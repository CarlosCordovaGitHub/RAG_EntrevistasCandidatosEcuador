# %%
# CELDA 1

import pandas as pd
import re
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import ast
from sentence_transformers import SentenceTransformer
import chromadb
from tqdm.notebook import tqdm
import torch

# Descargar stopwords en español (si no lo has hecho previamente)
# nltk.download('stopwords')
# nltk.download('punkt')

# Inicializar el stemmer y obtener las stopwords en español
stemmer = SnowballStemmer('spanish')
stop_words = set(stopwords.words('spanish'))
# Out:
# WARNING:tensorflow:From C:\Users\carlo\AppData\Roaming\Python\Python312\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv('unified_corpus.csv')

# %%
# Filtrar las columnas necesarias (incluir id y candidato)
corpus = df[['id', 'candidato_raw', 'temas_tratados_raw', 'descripcion_raw', 'entrevista_raw', 'entrevista_pre']]

# Limpiar el texto
def limpiar_texto(texto):
    texto = texto.lower()  
    texto = re.sub(r'\d+', '', texto)  
    texto = texto.translate(str.maketrans('', '', string.punctuation))  
    texto = texto.strip()  
    return texto

def procesar_texto(texto):
    texto = limpiar_texto(texto)  
    tokens = word_tokenize(texto, language='spanish')  
    tokens = [token for token in tokens if token not in stop_words]  
    tokens = [stemmer.stem(token) for token in tokens]  
    return ' '.join(tokens)

corpus['texto_completo'] = corpus['descripcion_raw'] + ' ' + corpus['entrevista_raw'] 

corpus['texto_completo_procesado'] = corpus['texto_completo'].apply(procesar_texto)

corpus.to_csv('corpus_procesado_con_texto_completo.csv', index=False)

print("El corpus procesado, incluyendo 'id', 'candidato', y la columna 'texto_completo_procesado', se ha guardado exitosamente en 'corpus_procesado_con_texto_completo.csv'.")
# Out:
# El corpus procesado, incluyendo 'id', 'candidato', y la columna 'texto_completo_procesado', se ha guardado exitosamente en 'corpus_procesado_con_texto_completo.csv'.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Usando dispositivo: {device}")
# Out:
# Usando dispositivo: cpu

# %%
model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')
model.to(device)
# Out:
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 128, 'do_lower_case': False}) with Transformer model: XLMRobertaModel
#   (1): Pooling({'word_embedding_dimension': 768, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
# )

# %%
df = pd.read_csv('corpus_procesado_con_texto_completo.csv')

# %%
print(df.head())
# Out:
#        id candidato_raw                                 temas_tratados_raw  \
# 0  WGE001  Wilson Gomez  Conformación del binomio presidencial; Relació...
# 1  WGE002  Wilson Gomez  Crisis del país; Propuestas de rescate y trans...
# 2  WGE003  Wilson Gomez  La necesidad de un cambio en el modelo educati...
# 3  WGP004  Wilson Gomez  El rol de la agricultura, la pesca y la indust...
# 4  WGP005  Wilson Gomez  Extracción de petróleo; Historia y auge de la ...
#
#                                      descripcion_raw  \
# 0  El documento es una entrevista en la que un ca...
# 1  El documento expone la visión y propuestas del...
# 2  El documento es una entrevista con el candidat...
# 3  El documento analiza el sector agropecuario y ...
# 4  El documento analiza tres sectores clave en Ec...
#
#                                       entrevista_raw  \
# 0  Yo vengo trabajando para muchos presidentes he...
# 1  Buenos días nos encontramos con Wilson Gómez c...
# 2  un gran abrazo para la inmensa audiencia de ra...
# 3  Parte 1: Diagnóstico de la Situación Actual La...
# 4  Parte 1: Extracción de petróleo en Ecuador Dia...
#
#                                       entrevista_pre  \
# 0  veng trabaj president oportun serv voluntari e...
# 1  buen dias encontr wilson gomez candidat presid...
# 2  gran abraz inmens audienci radi moren ecuador ...
# 3  part diagnost situacion actual agricultur pesc...
# 4  part extraccion petrole ecuador diagnost situa...
#
#                                       texto_completo  \
# 0  El documento es una entrevista en la que un ca...
# 1  El documento expone la visión y propuestas del...
# 2  El documento es una entrevista con el candidat...
# 3  El documento analiza el sector agropecuario y ...
# 4  El documento analiza tres sectores clave en Ec...
#
#                             texto_completo_procesado
# 0  document entrev candidat presidencial ecuador ...
# 1  document expon vision propuest candidat presid...
# 2  document entrev candidat presidencial enriqu g...
# 3  document analiz sector agropecuari pesquer ecu...
# 4  document analiz tres sector clav ecuador extra...

# %%
df_entrevistas = df[['id', 'candidato_raw', 'entrevista_raw', 'texto_completo_procesado']].copy()
print(df_entrevistas.head())
# Out:
#        id candidato_raw                                     entrevista_raw  \
# 0  WGE001  Wilson Gomez  Yo vengo trabajando para muchos presidentes he...
# 1  WGE002  Wilson Gomez  Buenos días nos encontramos con Wilson Gómez c...
# 2  WGE003  Wilson Gomez  un gran abrazo para la inmensa audiencia de ra...
# 3  WGP004  Wilson Gomez  Parte 1: Diagnóstico de la Situación Actual La...
# 4  WGP005  Wilson Gomez  Parte 1: Extracción de petróleo en Ecuador Dia...
#
#                             texto_completo_procesado
# 0  document entrev candidat presidencial ecuador ...
# 1  document expon vision propuest candidat presid...
# 2  document entrev candidat presidencial enriqu g...
# 3  document analiz sector agropecuari pesquer ecu...
# 4  document analiz tres sector clav ecuador extra...

# %%
print("Información del DataFrame de entrevistas:")
print(df_entrevistas.info())
print("\nPrimeras filas:")
print(df_entrevistas.head())
# Out:
# Información del DataFrame de entrevistas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        56 non-null     object
#  1   candidato_raw             56 non-null     object
#  2   entrevista_raw            56 non-null     object
#  3   texto_completo_procesado  56 non-null     object
# dtypes: object(4)
# memory usage: 1.9+ KB
# None
#
# Primeras filas:
#        id candidato_raw                                     entrevista_raw  \
# 0  WGE001  Wilson Gomez  Yo vengo trabajando para muchos presidentes he...
# 1  WGE002  Wilson Gomez  Buenos días nos encontramos con Wilson Gómez c...
# 2  WGE003  Wilson Gomez  un gran abrazo para la inmensa audiencia de ra...
# 3  WGP004  Wilson Gomez  Parte 1: Diagnóstico de la Situación Actual La...
# 4  WGP005  Wilson Gomez  Parte 1: Extracción de petróleo en Ecuador Dia...
#
#                             texto_completo_procesado
# 0  document entrev candidat presidencial ecuador ...
# 1  document expon vision propuest candidat presid...
# 2  document entrev candidat presidencial enriqu g...
# 3  document analiz sector agropecuari pesquer ecu...
# 4  document analiz tres sector clav ecuador extra...

# %%
def chunk_text(text, max_length=512):
    """Divide el texto en chunks más pequeños"""
    sentences = re.split(r'[.!?]+', text)
    chunks = []
    current_chunk = ""
    
    for sentence in sentences:
        sentence = sentence.strip()
        if not sentence:
            continue
            
        if len(current_chunk) + len(sentence) < max_length:
            current_chunk += sentence + ". "
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            current_chunk = sentence + ". "
    
    if current_chunk:
        chunks.append(current_chunk.strip())
        
    return chunks

# %%
documents = []        # Para los embeddings (texto limpio)
original_texts = []   # Para mostrar (texto original)
metadata_list = []
ids = []


print("Procesando entrevistas...")
for idx, row in tqdm(df_entrevistas.iterrows(), total=len(df_entrevistas)):
    # Usar entrevista_pre para embeddings
    texto_limpio = limpiar_texto(row['texto_completo_procesado'])
    # Guardar entrevista_raw para visualización
    texto_original = row['entrevista_raw']
    
    if texto_limpio:  # Solo procesar si hay texto
        # Dividir en chunks el texto limpio
        chunks = chunk_text(texto_limpio)
        # Dividir en chunks el texto original (misma longitud)
        chunks_originales = chunk_text(texto_original)
        
        # Almacenar cada chunk con sus metadatos
        for chunk_idx, (chunk, chunk_original) in enumerate(zip(chunks, chunks_originales)):
            documents.append(chunk)  # Para embeddings
            original_texts.append(chunk_original)  # Para mostrar
            metadata_list.append({
                "id_original": str(row["id"]),
                "candidato": row["candidato_raw"],
                "chunk_id": chunk_idx,
                "texto_original": chunk_original  # Guardamos el texto original en metadata
            })
            ids.append(f"entrevista_{row['id']}_chunk_{chunk_idx}")


print(f"Total de chunks generados: {len(documents)}")
# Out:
# Procesando entrevistas...
#   0%|          | 0/56 [00:00<?, ?it/s]
# Total de chunks generados: 56

# %%
print("Generando embeddings...")
embeddings = model.encode(documents, show_progress_bar=True)
# Out:
# Generando embeddings...
# Batches:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
chroma_client = chromadb.PersistentClient(path="./chroma_db")
collection_name = "entrevistas_candidatos"
collection = chroma_client.get_or_create_collection(name=collection_name)

# %%
batch_size = 100
print("Almacenando en ChromaDB...")
for i in tqdm(range(0, len(documents), batch_size)):
    end_idx = min(i + batch_size, len(documents))
    collection.add(
        documents=documents[i:end_idx],
        embeddings=embeddings[i:end_idx].tolist(),
        metadatas=metadata_list[i:end_idx],
        ids=ids[i:end_idx]
    )

print(f"Almacenamiento completado. Total de chunks: {len(documents)}")
# Out:
# Almacenando en ChromaDB...
#   0%|          | 0/1 [00:00<?, ?it/s]
# Insert of existing embedding ID: entrevista_WGE001_chunk_0
# Insert of existing embedding ID: entrevista_WGE002_chunk_0
# Insert of existing embedding ID: entrevista_WGE003_chunk_0
# Insert of existing embedding ID: entrevista_WGP004_chunk_0
# Insert of existing embedding ID: entrevista_WGP005_chunk_0
# Insert of existing embedding ID: entrevista_WGP006_chunk_0
# Insert of existing embedding ID: entrevista_WGP007_chunk_0
# Insert of existing embedding ID: entrevista_WGP008_chunk_0
# Insert of existing embedding ID: entrevista_VA1_chunk_0
# Insert of existing embedding ID: entrevista_VA2_chunk_0
# Insert of existing embedding ID: entrevista_VA3_chunk_0
# Insert of existing embedding ID: entrevista_LT1_chunk_0
# Insert of existing embedding ID: entrevista_LT2_chunk_0
# Insert of existing embedding ID: entrevista_LT3_chunk_0
# Insert of existing embedding ID: entrevista_LI1_chunk_0
# Insert of existing embedding ID: entrevista_LI2_chunk_0
# Insert of existing embedding ID: entrevista_LI3_chunk_0
# Insert of existing embedding ID: entrevista_HK1_chunk_0
# Insert of existing embedding ID: entrevista_HK2_chunk_0
# Insert of existing embedding ID: entrevista_HK3_chunk_0
# Insert of existing embedding ID: entrevista_IS1_chunk_0
# Insert of existing embedding ID: entrevista_IS2_chunk_0
# Insert of existing embedding ID: entrevista_HC1_chunk_0
# Insert of existing embedding ID: entrevista_HC2_chunk_0
# Insert of existing embedding ID: entrevista_HC3_chunk_0
# Insert of existing embedding ID: entrevista_FT1_chunk_0
# Insert of existing embedding ID: entrevista_FT2_chunk_0
# Insert of existing embedding ID: entrevista_FT3_chunk_0
# Insert of existing embedding ID: entrevista_LG1_chunk_0
# Insert of existing embedding ID: entrevista_LG2_chunk_0
# Insert of existing embedding ID: entrevista_LG3_chunk_0
# Insert of existing embedding ID: entrevista_JC1_chunk_0
# Insert of existing embedding ID: entrevista_JC2_chunk_0
# Insert of existing embedding ID: entrevista_JC3_chunk_0
# Insert of existing embedding ID: entrevista_AG1_chunk_0
# Insert of existing embedding ID: entrevista_AG2_chunk_0
# Insert of existing embedding ID: entrevista_AG3_chunk_0
# Insert of existing embedding ID: entrevista_PG1_chunk_0
# Insert of existing embedding ID: entrevista_PG2_chunk_0
# Insert of existing embedding ID: entrevista_PG3_chunk_0
# Insert of existing embedding ID: entrevista_JE1_chunk_0
# Insert of existing embedding ID: entrevista_JE2_chunk_0
# Insert of existing embedding ID: entrevista_JE3_chunk_0
# Insert of existing embedding ID: entrevista_JJ1_chunk_0
# Insert of existing embedding ID: entrevista_JJ2_chunk_0
# Insert of existing embedding ID: entrevista_JJ3_chunk_0
# Insert of existing embedding ID: entrevista_CR1_chunk_0
# Insert of existing embedding ID: entrevista_CR2_chunk_0
# Insert of existing embedding ID: entrevista_CR3_chunk_0
# Insert of existing embedding ID: entrevista_DNE001_chunk_0
# Insert of existing embedding ID: entrevista_DNE002_chunk_0
# Insert of existing embedding ID: entrevista_DNE003_chunk_0
# Insert of existing embedding ID: entrevista_DNP004_chunk_0
# Insert of existing embedding ID: entrevista_DNP005_chunk_0
# Insert of existing embedding ID: entrevista_DNP006_chunk_0
# Insert of existing embedding ID: entrevista_DNP007_chunk_0
# Add of existing embedding ID: entrevista_WGE001_chunk_0
# Add of existing embedding ID: entrevista_WGE002_chunk_0
# Add of existing embedding ID: entrevista_WGE003_chunk_0
# Add of existing embedding ID: entrevista_WGP004_chunk_0
# Add of existing embedding ID: entrevista_WGP005_chunk_0
# Add of existing embedding ID: entrevista_WGP006_chunk_0
# Add of existing embedding ID: entrevista_WGP007_chunk_0
# Add of existing embedding ID: entrevista_WGP008_chunk_0
# Add of existing embedding ID: entrevista_VA1_chunk_0
# Add of existing embedding ID: entrevista_VA2_chunk_0
# Add of existing embedding ID: entrevista_VA3_chunk_0
# Add of existing embedding ID: entrevista_LT1_chunk_0
# Add of existing embedding ID: entrevista_LT2_chunk_0
# Add of existing embedding ID: entrevista_LT3_chunk_0
# Add of existing embedding ID: entrevista_LI1_chunk_0
# Add of existing embedding ID: entrevista_LI2_chunk_0
# Add of existing embedding ID: entrevista_LI3_chunk_0
# Add of existing embedding ID: entrevista_HK1_chunk_0
# Add of existing embedding ID: entrevista_HK2_chunk_0
# Add of existing embedding ID: entrevista_HK3_chunk_0
# Add of existing embedding ID: entrevista_IS1_chunk_0
# Add of existing embedding ID: entrevista_IS2_chunk_0
# Add of existing embedding ID: entrevista_HC1_chunk_0
# Add of existing embedding ID: entrevista_HC2_chunk_0
# Add of existing embedding ID: entrevista_HC3_chunk_0
# Add of existing embedding ID: entrevista_FT1_chunk_0
# Add of existing embedding ID: entrevista_FT2_chunk_0
# Add of existing embedding ID: entrevista_FT3_chunk_0
# Add of existing embedding ID: entrevista_LG1_chunk_0
# Add of existing embedding ID: entrevista_LG2_chunk_0
# Add of existing embedding ID: entrevista_LG3_chunk_0
# Add of existing embedding ID: entrevista_JC1_chunk_0
# Add of existing embedding ID: entrevista_JC2_chunk_0
# Add of existing embedding ID: entrevista_JC3_chunk_0
# Add of existing embedding ID: entrevista_AG1_chunk_0
# Add of existing embedding ID: entrevista_AG2_chunk_0
# Add of existing embedding ID: entrevista_AG3_chunk_0
# Add of existing embedding ID: entrevista_PG1_chunk_0
# Add of existing embedding ID: entrevista_PG2_chunk_0
# Add of existing embedding ID: entrevista_PG3_chunk_0
# Add of existing embedding ID: entrevista_JE1_chunk_0
# Add of existing embedding ID: entrevista_JE2_chunk_0
# Add of existing embedding ID: entrevista_JE3_chunk_0
# Add of existing embedding ID: entrevista_JJ1_chunk_0
# Add of existing embedding ID: entrevista_JJ2_chunk_0
# Add of existing embedding ID: entrevista_JJ3_chunk_0
# Add of existing embedding ID: entrevista_CR1_chunk_0
# Add of existing embedding ID: entrevista_CR2_chunk_0
# Add of existing embedding ID: entrevista_CR3_chunk_0
# Add of existing embedding ID: entrevista_DNE001_chunk_0
# Add of existing embedding ID: entrevista_DNE002_chunk_0
# Add of existing embedding ID: entrevista_DNE003_chunk_0
# Add of existing embedding ID: entrevista_DNP004_chunk_0
# Add of existing embedding ID: entrevista_DNP005_chunk_0
# Add of existing embedding ID: entrevista_DNP006_chunk_0
# Add of existing embedding ID: entrevista_DNP007_chunk_0
# Almacenamiento completado. Total de chunks: 56

# %%
def search_documents(query, n_results=5):
    """
    Función de búsqueda mejorada que siempre retorna resultados
    """
    collection = chromadb.PersistentClient(path="./chroma_db").get_or_create_collection("entrevistas_candidatos")
    
    # Generar embedding de la query
    query_embedding = model.encode(query).tolist()
    
    # Realizar la búsqueda en ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=n_results,  # Directamente pedimos los n_results que queremos
        include=["metadatas", "distances", "documents"]
    )
    
    # Extraer los resultados
    distances = results['distances'][0]
    metadatas = results['metadatas'][0]
    documents = results['documents'][0]
    
    # Crear lista de resultados
    enhanced_results = []
    for i, (distance, metadata, document) in enumerate(zip(distances, metadatas, documents)):
        # Normalizar la similitud para que esté entre 0 y 1
        max_distance = max(distances)
        min_distance = min(distances)
        normalized_similarity = (max_distance - distance) / (max_distance - min_distance) if max_distance != min_distance else 1
        
        enhanced_results.append({
            'metadata': metadata,
            'similarity': normalized_similarity,
            'final_score': normalized_similarity,
            'texto': document
        })
    
    # Ordenar por score final
    enhanced_results.sort(key=lambda x: x['final_score'], reverse=True)
    
    return enhanced_results

# %%
def mostrar_resultados(resultados):
    """
    Muestra los resultados de búsqueda de manera clara
    """
    if not resultados:
        print("\nNo se encontraron resultados.")
        return
        
    print("\n=== Resultados de la búsqueda ===\n")
    for i, resultado in enumerate(resultados, 1):
        print(f"\n--- Resultado {i} ---")
        print(f"Candidato: {resultado['metadata']['candidato']}")
        print(f"Relevancia: {resultado['similarity']:.2%}")  
        print("\nTexto:")
        print(f"{resultado['metadata']['texto_original']}")
        print("\n" + "="*50)

# %%
# Probar con varias queries
# Lista para almacenar los resultados
data = []
queries = [
    "¿ cuales son las propuestas para la seguridad?",
]

for query in queries:
    print(f"\nBuscando: '{query}'")
    resultados = search_documents(query, n_results=5)  # Siempre mostrará 3 resultados
    mostrar_resultados(resultados)
# Out:
# Buscando: '¿ cuales son las propuestas para la seguridad?'
#
# === Resultados de la búsqueda ===
#
#
# --- Resultado 1 ---
# Candidato: Victor Araus
# Relevancia: 100.00%
#
# Texto:
# Contamos con la presencia en esta mesa con el candidato a la presidencia Víctor araus pueblo igualdad y democracia listas cuatro bienvenido general doctor Apolo gracias por la invitación llamó mucho la atención su vestimenta el día del del debate más menos parecida al del presidente buele y también una frase que usted dijo un poco parafraseando a pu Cuando decía que perdonar a delincuentes le corresponde a Dios y enviárselos a Dios le corresponde a usted corresponde a m correcto eso en el término de lenguaje no verbal Más allá de firmeza transmitiría la posibilidad de un sesgo autocrático y ahí viene la pregunta y es general usted es demócrata o autócrata me permite cambiar por un momento los papeles doctor Apolo por supuesto por un momentito para dar la seguridad que usted sus hijos y sus nietos necesitan Hay que ser demócrata autócrata de izquierda o de derecha hay que contar con leyes con leyes que sean aplicables y que no le den la salida a los jueces para la sinvergüencería de la sustitu llegamos donde yo quería llegar me explico esta propuesta de Víctor araus tiene un estudio jurídico sumamente profundo mi equipo jurídico lo ha analizado porque como digo yo perdóname perderle la informalidad un poco ya estamos viejos pues para decir cosas sin sentido para equivocarnos para cometer esas ligere zas eso tiene un sustento legal va de la mano con yo liberar al Ecuador de los tratados internacionales para la pena de muerte como le interprete una parte de la población o no va más allá porque aquí ha llorado pues una madre que ha tenido unja violada doctor Apolo aquí que ha llorado una madre que ha quedado viuda a ha llorado un padre que ha perdido sus hijos por asesinos que ha llorado una familia de un niño violado entonces internacionales no va a ser fácil pero es posible y hay que dar el primer paso y voy a tener 50,000 problemas a la solución que yo estoy planteando de personas que no tienen el carácter de la decisión como la tengo yo doctor de devolverle al Ecuador esa paz y esa tranquilidad que todos necesitan y se merecen que se merece un miserable que viola a un niño que se merece un miserable que mata a un ser humano a un ser de bien Es obligación del Estado doctor acabar con la vida del delincuente Hasta que el delincuente acabe con la vida del ciudadano por eso en mi gobierno ningún policía tendrá miedo de darle bala al delincuente armado que ponga en riesgo la vida de un ciudadano todo tiene que ir de la mano con la ley Usted dijo se necesitan leyes y una verdadera aplicación transparente de las leyes la gente no confía porque saben que hay una judicatura que se encuentra totalmente corrupta una fiscalía totalmente corrupta pero para eso tiene que haber un liderazgo tiene que haber una cabeza que es el presidente que sin querer meter la mano en otras instituciones del estado tiene toda la potestad de exigir que las cosas se hagan transparentemente doctor
araus modestia parte el general más representativo en su momento que tuvo la Policía Nacional el general más condecorado de la historia de la Policía Nacional 10 de con decoraciones internacionales y lo paradójico cuatro por el gobierno americano por mi lucha contra el narcotráfico Por qué se reunió con Danilo Carrera y con con porque yo le advertí a César monje que esté pendiente de la calificación y de mi ascenso y sabe que me respondió el ministro la autoridad máxima de la policía que él no se metía en eso que eso Estaba tratando la ex comandante general directamente con el presidente lazo Imagínese Milton qué poder tenía la comandante general que el ministro no opina que tiene que ha cheves en todo esto por qué Porque no sabía quién era ches yo no sabía quién era pero usted era general de la policía parte de la cúpula de la policía no se sabía esa investigación no tenía conocimiento Dios sabe que lo que digo cu se enteró lo que pasaba espérese entonces a mí César monje me dice quien te puede sacar la cita es Danilo Carrera pero yo no soy amigo de Danilo Carrera lo conocía porque era una persona pública en Guayaquil te va a llamar una persona que te va a contactar con él y me llama Rubén cherrez y me dice me dijo César monje que lo reuna con con con César co ...
#
# ==================================================
#
# --- Resultado 4 ---
# Candidato: Daniel Noboa
# Relevancia: 3.68%
#
# Texto:
# Un Ecuador conectado, preparado para el futuro, con ciudades resilientes y ecosistemas protegidos Conservación ambiental, adaptación y mitigación al cambio climático Promover la conservación y protección del medio ambiente, la conservación de la biodiversidad y el desarrollo sostenible como pilares fundamentales del desarrollo económico y social del Ecuador, así como la transición hacia una economía verde y con energías renovables.
#
# ==================================================
#
# --- Resultado 5 ---
# Candidato: Carlos Rabascall
# Relevancia: 0.00%
#
# Texto:
# [00:00] [Aplausos] radio sucesos 101.
#
# ==================================================

# %%
for query in queries:
    print(f"\nBuscando: '{query}'")
    resultados = search_documents(query, n_results=5)

    # Ver la estructura de los resultados
    print("aqui: " + str(resultados))  # <-- Agregar esta línea para depuración

    for res in resultados:
        print(res.keys())  # <-- Ver qué claves tiene cada resultado
# Out:
# Buscando: '¿ cuales son las propuestas para la seguridad?'
# aqui: [{'metadata': {'candidato': 'Victor Araus', 'chunk_id': 0, 'id_original': 'VA3', 'texto_original': 'Contamos con la presencia en esta mesa con el candidato a la presidencia Víctor araus pueblo igualdad y democracia listas cuatro bienvenido general doctor Apolo gracias por la invitación llamó mucho la atención su vestimenta el día del del debate más menos parecida al del presidente buele y también una frase que usted dijo un poco parafraseando a pu Cuando decía que perdonar a delincuentes le corresponde a Dios y enviárselos a Dios le corresponde a usted corresponde a m correcto eso en el término de lenguaje no verbal Más allá de firmeza transmitiría la posibilidad de un sesgo autocrático y ahí viene la pregunta y es general usted es demócrata o autócrata me permite cambiar por un momento los papeles doctor Apolo por supuesto por un momentito para dar la seguridad que usted sus hijos y sus nietos necesitan Hay que ser demócrata autócrata de izquierda o de derecha hay que contar con leyes con leyes que sean aplicables y que no le den la salida a los jueces para la sinvergüencería de la sustitu llegamos donde yo quería llegar me explico esta propuesta de Víctor araus tiene un estudio jurídico sumamente profundo mi equipo jurídico lo ha analizado porque como digo yo perdóname perderle la informalidad un poco ya estamos viejos pues para decir cosas sin sentido para equivocarnos para cometer esas ligere zas eso tiene un sustento legal va de la mano con yo liberar al Ecuador de los tratados internacionales para la pena de muerte como le interprete una parte de la población o no va más allá porque aquí ha llorado pues una madre que ha tenido unja violada doctor Apolo aquí que ha llorado una madre que ha quedado viuda a ha llorado un padre que ha perdido sus hijos por asesinos que ha llorado una familia de un niño violado entonces internacionales no va a ser fácil pero es posible y hay que dar el primer paso y voy a tener 50,000 problemas a la solución que yo estoy planteando de personas que no tienen el carácter de la decisión como la tengo yo doctor de devolverle al Ecuador esa paz y esa tranquilidad que todos necesitan y se merecen que se merece un miserable que viola a un niño que se merece un miserable que mata a un ser humano a un ser de bien Es obligación del Estado doctor acabar con la vida del delincuente Hasta que el delincuente acabe con la vida del ciudadano por eso en mi gobierno ningún policía tendrá miedo de darle bala al delincuente armado que ponga en riesgo la vida de un ciudadano todo tiene que ir de la mano con la ley Usted dijo se necesitan leyes y una verdadera aplicación transparente de las leyes la gente no confía porque saben que hay una judicatura que se encuentra totalmente corrupta una fiscalía totalmente corrupta pero para eso tiene que haber un liderazgo tiene que haber una cabeza que es el presidente que sin querer meter la mano en otras instituciones del estado tiene toda la potestad de exigir que las cosas se hagan transparentemente doctor por eso uno de mis planteamientos es crear una mesa donde y y crear la secretaría nacional de seguridad y protección ciudadana para que toda las instituciones que luchan contra el crimen policía militares fuerzas armadas minister de gobierno el interior wafe la misma fiscalía la misma judicatura luchen para sacar a los delincuentes de las calles Pero por qué no vemos al otro lado para evitar Pues que regresen a las 48 horas doctor a seguir delinquiendo hay cerca de 20,000 procesos de pillos de delincuentes que tienen 14 15 20 detenciones con medidas sustitutivas y no por cruzarse la luz roja doctor Ese es la realidad entiendo la preocupación de personas sensatas preparadas letradas como usted que dice que tiene que ir de la m la ley de acuerdo pero por algo se empieza primero planteando la posibilidad de liberar al Ecuador yo no le voy a exponer al país a sanciones internacionales doctor Pero sí es posible que no es fácil de acuerdo pero alguien tiene que dar el  ...
# dict_keys(['metadata', 'similarity', 'final_score', 'texto'])
# dict_keys(['metadata', 'similarity', 'final_score', 'texto'])
# dict_keys(['metadata', 'similarity', 'final_score', 'texto'])
# dict_keys(['metadata', 'similarity', 'final_score', 'texto'])
# dict_keys(['metadata', 'similarity', 'final_score', 'texto'])

# %%
import ollama

def buscar_documentos(query, n_results=5):
    """
    Simula una búsqueda de documentos relevantes.
    Reemplázala con una búsqueda real en tu sistema (por ejemplo, en ChromaDB).
    """
    documentos = [
        {"texto": "El candidato A propone bajar el IVA para mejorar la economía."},
        {"texto": "El candidato B menciona que reducirá impuestos para fomentar el empleo."},
        {"texto": "Candidato C planea eliminar impuestos en ciertos sectores."},
        {"texto": "Candidato D habla sobre políticas fiscales para aumentar la inversión."},
        {"texto": "El candidato E sugiere una reforma fiscal que afectaría a las grandes empresas."}
    ]
    
    return documentos[:n_results]  # Devuelve los primeros 'n_results' documentos

def obtener_resumen_ollama(query, resultados):
    """
    Genera un resumen de los documentos utilizando Ollama.
    """
    textos = [r["texto"] for r in resultados]  # Extraer el texto de cada resultado

    prompt = (
        f"Esto es lo que he encontrado sobre la consulta: {query}\n\n"
        + "\n".join(textos)
        + "\n\nGenera un resumen basado en estos resultados."
    )

    try:
        respuesta = ollama.chat(model='llama3.2:latest', messages=[{'role': 'user', 'content': prompt}])
        return respuesta['message']['content']
    except Exception as e:
        print(f"Error al llamar a Ollama: {str(e)}")
        return None

# 🔹 **Prueba con una consulta**
query_text = "bajar el IVA para fortalecer la economía"

print("\n🔍 Buscando documentos relevantes...")
resultados = buscar_documentos(query_text, n_results=5)  # Simulación de búsqueda

print("\n📑 Generando resumen con Ollama...")
respuesta_ollama = obtener_resumen_ollama(query_text, resultados)

# Imprimir la respuesta generada por Ollama
if respuesta_ollama:
    print("\n📝 Resumen de Ollama:")
    print(respuesta_ollama)
# Out:
# 🔍 Buscando documentos relevantes...
#
# 📑 Generando resumen con Ollama...
#
# 📝 Resumen de Ollama:
# **Resumen de las propuestas de impuestos**
#
# Los candidatos presentan diferentes propuestas para abordar el problema económico del país:
#
# *   **Candidato A**: Bajar el IVA (Impuesto al Valor Agregado) para fortalecer la economía.
# *   **Candidato B**: Reducir impuestos para fomentar el empleo.
# *   **Candidato C**: Eliminar impuestos en ciertos sectores para reducir la carga fiscal y estimular la creación de empleo.
# *   **Candidato D**: Implementar políticas fiscales para aumentar la inversión en la economía, lo que podría generar más empleos y crecimiento económico.
# *   **Candidato E**: Propone una reforma fiscal que afectaría a las grandes empresas, sin proporcionar detalles específicos sobre cómo se implementaría.
#
# En general, todas estas propuestas buscan reducir la carga fiscal y estimular el crecimiento económico, pero de diferentes maneras. Algunas sugieren reducir impuestos para fomentar el empleo o eliminar impuestos en ciertos sectores, mientras que otras proponen políticas fiscales más generales para aumentar la inversión y estimular la economía.
#
# Es importante tener en cuenta que estas propuestas pueden tener diferentes efectos en la economía y en los diferentes sectores de la población. Por lo tanto, es fundamental analizar cada propuesta detalladamente y considerar las posibles consecuencias antes de tomar una decisión.

# %%
import ollama
import chromadb

def mostrar_resultados(resultados, query):
    """
    Muestra los resultados de búsqueda de manera clara y genera un resumen con Ollama.
    """
    if not resultados:
        print("\nNo se encontraron resultados.")
        return

    print("\n=== Resultados de la búsqueda ===\n")
    for i, resultado in enumerate(resultados, 1):
        print(f"\n--- Resultado {i} ---")
        print(f"Candidato: {resultado['metadata']['candidato']}")
        print(f"Relevancia: {resultado['similarity']:.2%}")  
        print("\nTexto:")
        print(f"{resultado['metadata']['texto_original']}")
        print("\n" + "="*50)

    # 🔹 Generar resumen con Ollama
    respuesta_ollama = obtener_resumen_ollama(query, resultados)

    if respuesta_ollama:
        print("\n📝 Resumen de Ollama:")
        print(respuesta_ollama)

def obtener_resumen_ollama(query, resultados):
    """
    Genera un resumen estructurado de los documentos utilizando Ollama.
    """
    textos = [f"- {r['metadata']['candidato']}: {r['metadata']['texto_original']}" for r in resultados]

    prompt = (
        f"Consulta: {query}\n\n"
        "He encontrado las siguientes propuestas de los candidatos:\n"
        + "\n".join(textos)
        + "\n\nGenera un resumen estructurado con los siguientes elementos:\n"
        "- Breve resumen individual por candidato.\n"
        "- Una conclusión general sobre los enfoques de los candidatos.\n"
        "Responde de manera clara y concisa."
    )

    try:
        respuesta = ollama.chat(model='llama3.2:latest', messages=[{'role': 'user', 'content': prompt}])
        return respuesta['message']['content']
    except Exception as e:
        print(f"Error al llamar a Ollama: {str(e)}")
        return None


def search_documents(query, n_results=5):
    """
    Función de búsqueda en ChromaDB que retorna documentos relevantes.
    """
    collection = chromadb.PersistentClient(path="./chroma_db").get_or_create_collection("entrevistas_candidatos")

    # Generar embedding de la query
    query_embedding = model.encode(query).tolist()

    # Realizar la búsqueda en ChromaDB
    results = collection.query(
        query_embeddings=[query_embedding],
        n_results=n_results,
        include=["metadatas", "distances", "documents"]
    )

    # Extraer los resultados
    distances = results['distances'][0]
    metadatas = results['metadatas'][0]
    documents = results['documents'][0]

    # Crear lista de resultados con similitud normalizada
    enhanced_results = []
    max_distance = max(distances)
    min_distance = min(distances)
    
    for i, (distance, metadata, document) in enumerate(zip(distances, metadatas, documents)):
        normalized_similarity = (max_distance - distance) / (max_distance - min_distance) if max_distance != min_distance else 1
        enhanced_results.append({
            'metadata': metadata,
            'similarity': normalized_similarity,
            'final_score': normalized_similarity,
            'texto': document
        })

    # Ordenar por score final
    enhanced_results.sort(key=lambda x: x['final_score'], reverse=True)

    return enhanced_results

# 🔹 Probar con varias queries
queries = [
    "¿Cuáles son las propuestas para la seguridad?",
    "Sobre que se centra las propuestas de daniel noboa?"
]

for query in queries:
    print(f"\n🔍 Buscando: '{query}'")
    resultados = search_documents(query, n_results=5)  # Buscar en ChromaDB
    mostrar_resultados(resultados, query)  # Mostrar y generar resumen
# Out:
# 🔍 Buscando: '¿Cuáles son las propuestas para la seguridad?'
#
# === Resultados de la búsqueda ===
#
#
# --- Resultado 1 ---
# Candidato: Victor Araus
# Relevancia: 100.00%
#
# Texto:
# Contamos con la presencia en esta mesa con el candidato a la presidencia Víctor araus pueblo igualdad y democracia listas cuatro bienvenido general doctor Apolo gracias por la invitación llamó mucho la atención su vestimenta el día del del debate más menos parecida al del presidente buele y también una frase que usted dijo un poco parafraseando a pu Cuando decía que perdonar a delincuentes le corresponde a Dios y enviárselos a Dios le corresponde a usted corresponde a m correcto eso en el término de lenguaje no verbal Más allá de firmeza transmitiría la posibilidad de un sesgo autocrático y ahí viene la pregunta y es general usted es demócrata o autócrata me permite cambiar por un momento los papeles doctor Apolo por supuesto por un momentito para dar la seguridad que usted sus hijos y sus nietos necesitan Hay que ser demócrata autócrata de izquierda o de derecha hay que contar con leyes con leyes que sean aplicables y que no le den la salida a los jueces para la sinvergüencería de la sustitu llegamos donde yo quería llegar me explico esta propuesta de Víctor araus tiene un estudio jurídico sumamente profundo mi equipo jurídico lo ha analizado porque como digo yo perdóname perderle la informalidad un poco ya estamos viejos pues para decir cosas sin sentido para equivocarnos para cometer esas ligere zas eso tiene un sustento legal va de la mano con yo liber
# 2. **Carlos Rabascall** (sin información detallada sobre su propuesta).
#
# 3. **Otro candidato** (no se proporcionó su nombre ni detalles sobre su plataforma política).
#
# **Conclusión General**
#
# Los candidatos presentan enfoques diferentes para el futuro de Ecuador, pero comparten la importancia de la conservación ambiental y el desarrollo sostenible. Daniel Noboa destaca la conexión y preparación del país para el futuro, mientras que enfatiza la protección del medio ambiente. La ausencia de información detallada sobre las propuestas de Carlos Rabascall y el otro candidato limita su análisis. En general, los candidatos coinciden en la necesidad de un enfoque más sostenible para el desarrollo económico y social de Ecuador, pero divergen en sus estrategias específicas.
#
# 🔍 Buscando: 'Sobre que se centra las propuestas de daniel noboa?'
#
# === Resultados de la búsqueda ===
#
#
# --- Resultado 1 ---
# Candidato: Daniel Noboa
# Relevancia: 100.00%
#
# Texto:
# la unidad nacional en pro de la paz y la seguridad en el Ecuador la revista de opinión democracia Presenta una edición especial este lunes 23 de diciembre del 2024 partiendo de una premisa queremos desearles a los miles de Seguidores una feliz navidad y un próspero año 2025 buscando la verdad Bienvenido al señor presidente de la república Daniel novoo asín Esta es una entrevista de radio democracia a la que se suman varias emisoras a nivel nacional a todas las que se les da también la bienvenida sin perjuicio de analizar lo ocurrido durante el 2024 Especialmente los últimos acontecimientos quisiera enfocar también en los temas de futuro de la expectativa que tienen los Ecuatorianos de este 2025 de los grandes desafíos del Ecuador no solo por el proceso electoral sino por las grandes expectativas que tienen los Ecuatorianos por mejores días porque tenga certidumbre frente a la inseguridad ciudadana en medio del conflicto armado interno que en enero de este año fue decretado certidumbre en los servicios básicos parte tiene que ver con los gobiernos autónomos descentralizados pero también de el gobierno nacional como la provisión de energía eléctrica partiendo de un hecho que hay responsabilidad como lo hemos repetido en la radio de todos los gobiernos Por cierto hay que dar la dimensión gobierno de un año un mes gobierno de 2 años y medio gobierno de 4 años y un gobierno que tuvo 10 años en el poder y que lamentablemente para el país con todos los recursos que dij no pudo por lo menos sentar las bases para una matriz energética equilibrada una infraestructura bien mantenida una inversión suficiente no la insuficiente que ha habido Durante los últimos años un marco legal actualizado y no obsoleto que hubo que hacer durante el último año queremos hablar temas básicos y fundamentales como la generación de fuentes de empleo pleno en el Ecuador el impulso a los emprendedores la educación la salud la seguridad social la atención real y la solución a los problemas del agro ecuatoriano entre otros más allá de un proceso electoral en el cual se busca cosechar réditos entre los actores a Costa de la confrontación electoral que no construye sino que busca la destrucción del contrario y no sembrar esperanza en los Ecuatorianos con planteamientos claros de soluciones Cómo piensan los candidatos solucionar los acuciantes problemas que viven los Ecuatorianos es decir pretendemos siendo el puente entre ustedes miles de Seguidores y el presidente de la república entregarles información Útil para los ciudadanos quiero empezar luego de la bienvenida al Señor Presidente con un tema de coyuntura la desaparición de los cuatro chicos Jos Ismael sa Steven en el sur de Guayaquil sin entrar en especulaciones que no acostumbramos sin información responsable de primera mano Este es un tema delicado más aún cuando estamos en proceso electoral y se busca protagonismo penosamente lo condenable a Costa de un dolor familiar se ha mencionado que hubo un operativo militar Y desde